# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
import pandas as pd

# %%
house_df = pd.read_csv('realtor-data.csv', sep=',', header=0, encoding= 'utf_8')

# %%
house_df.dtypes
# Out:
# status           object
# price           float64
# bed             float64
# bath            float64
# acre_lot        float64
# full_address     object
# street           object
# city             object
# state            object
# zip_code        float64
# house_size      float64
# sold_date        object
# dtype: object

# %%
house_df.shape
# Out:
# (203126, 12)

# %%
house_df.describe()
# Out:
#               price            bed           bath       acre_lot  \
# count  2.031260e+05  171963.000000  172835.000000  151066.000000
# mean   8.683271e+05       3.534493       2.620129       8.730882
# std    1.433730e+06       2.696704       2.939190     634.635361
# min    1.000000e+00       1.000000       1.000000       0.000000
# 25%    2.499000e+05       2.000000       2.000000       0.130000
# 50%    5.199000e+05       3.000000       2.000000       0.330000
# 75%    8.899000e+05       4.000000       3.000000       1.140000
# max    6.000000e+07      99.000000     198.000000  100000.000000
#
#             zip_code    house_size
# count  202931.000000  1.734480e+05
# mean     2159.784769  2.234716e+03
# std      1743.024350  4.221611e+03
# min       601.000000  1.000000e+02
# 25%      1230.000000  1.152000e+03
# 50%      2025.000000  1.728000e+03
# 75%      2176.000000  2.634000e+03
# max     99999.000000  1.450112e+06

# %%
house_df.head(100)
# Out:
#       status     price  bed  bath  acre_lot  \
# 0   for_sale  105000.0  3.0   2.0      0.12
# 1   for_sale   80000.0  4.0   2.0      0.08
# 2   for_sale   67000.0  2.0   1.0      0.15
# 3   for_sale  145000.0  4.0   2.0      0.10
# 4   for_sale   65000.0  6.0   2.0      0.05
# ..       ...       ...  ...   ...       ...
# 95  for_sale  260000.0  4.0   2.0      0.12
# 96  for_sale   31179.0  NaN   NaN      0.13
# 97  for_sale  500000.0  4.0   3.0      0.33
# 98  for_sale  225000.0  3.0   2.0      0.21
# 99  for_sale   28000.0  NaN   NaN      0.25
#
#                                          full_address  \
# 0   Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1             Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2             556G 556-G 16 St, Juana Diaz, PR, 00795
# 3   R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                     14 Navarro, Mayaguez, PR, 00680
# ..                                                ...
# ...

# %%
house_df.value_counts('status')
# Out:
# status
# for_sale          202452
# ready_to_build       674
# dtype: int64

# %%
import numpy as np

# %%
house_df=house_df.replace([np.inf, -np.inf], np.nan)

# %%
house_df=house_df.drop_duplicates()

# %%
house_df.duplicated().values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
house_df.drop_duplicates().reset_index(drop=True)
# Out:
#          status      price  bed  bath  acre_lot  \
# 0      for_sale   105000.0  3.0   2.0      0.12
# 1      for_sale    80000.0  4.0   2.0      0.08
# 2      for_sale    67000.0  2.0   1.0      0.15
# 3      for_sale   145000.0  4.0   2.0      0.10
# 4      for_sale    65000.0  6.0   2.0      0.05
# ...         ...        ...  ...   ...       ...
# 20914  for_sale  1299000.0  NaN   NaN      1.33
# 20915  for_sale   899000.0  NaN   NaN      0.35
# 20916  for_sale   185000.0  NaN   NaN      1.19
# 20917  for_sale  1850000.0  4.0   4.0      0.28
# 20918  for_sale  2100000.0  4.0   4.0      1.52
#
#                                             full_address  \
# 0      Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                556G 556-G 16 St, Juana Diaz, PR, 00795
# 3      R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                        14 Navarro, Mayaguez, PR, 00680
# ...

# %%
house_df.dropna()
# Out:
#           status      price  bed  bath  acre_lot  \
# 829     for_sale   110000.0  7.0   3.0      0.09
# 10344   for_sale   950000.0  5.0   4.0      0.99
# 10351   for_sale  6899000.0  4.0   6.0      0.83
# 24237   for_sale   525000.0  3.0   3.0      0.45
# 24238   for_sale   289900.0  3.0   2.0      0.36
# ...          ...        ...  ...   ...       ...
# 203051  for_sale   545000.0  2.0   1.0      0.15
# 203053  for_sale   599000.0  5.0   2.0      0.40
# 203056  for_sale   749000.0  2.0   1.0      0.26
# 203058  for_sale   495000.0  3.0   2.0      0.15
# 203082  for_sale  3995000.0  6.0   7.0      1.18
#
#                                      full_address                street  \
# 829            B-2 Monte Elena, Dorado, PR, 00949       B-2 Monte Elena
# 10344      46 Water Isle, Saint Thomas, VI, 00802         46 Water Isle
# 10351      10 Water Isle, Saint Thomas, VI, 00802         10 Water Isle
# 24237             955 River Rd, Agawam, MA, 01001          955 River Rd
# ...

# %%
house_df.dtypes
# Out:
# status           object
# price           float64
# bed             float64
# bath            float64
# acre_lot        float64
# full_address     object
# street           object
# city             object
# state            object
# zip_code        float64
# house_size      float64
# sold_date        object
# dtype: object

# %%
house_df.head(500)
# Out:
#        status     price  bed  bath  acre_lot  \
# 0    for_sale  105000.0  3.0   2.0      0.12
# 1    for_sale   80000.0  4.0   2.0      0.08
# 2    for_sale   67000.0  2.0   1.0      0.15
# 3    for_sale  145000.0  4.0   2.0      0.10
# 4    for_sale   65000.0  6.0   2.0      0.05
# ..        ...       ...  ...   ...       ...
# 809  for_sale   75200.0  3.0   1.0      0.09
# 813  for_sale  160000.0  NaN   NaN      0.49
# 817  for_sale  119000.0  NaN   NaN      1.29
# 818  for_sale  497000.0  NaN   NaN       NaN
# 820  for_sale   89000.0  NaN   NaN      0.22
#
#                                           full_address  \
# 0    Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1              Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2              556G 556-G 16 St, Juana Diaz, PR, 00795
# 3    R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                      14 Navarro, Mayaguez, PR, 00680
# ..                                                 ...
# ...

# %%
type(house_df)
# Out:
# pandas.core.frame.DataFrame

# %%
house_df=house_df.dropna()
house_df
# Out:
#           status      price  bed  bath  acre_lot  \
# 829     for_sale   110000.0  7.0   3.0      0.09
# 10344   for_sale   950000.0  5.0   4.0      0.99
# 10351   for_sale  6899000.0  4.0   6.0      0.83
# 24237   for_sale   525000.0  3.0   3.0      0.45
# 24238   for_sale   289900.0  3.0   2.0      0.36
# ...          ...        ...  ...   ...       ...
# 203051  for_sale   545000.0  2.0   1.0      0.15
# 203053  for_sale   599000.0  5.0   2.0      0.40
# 203056  for_sale   749000.0  2.0   1.0      0.26
# 203058  for_sale   495000.0  3.0   2.0      0.15
# 203082  for_sale  3995000.0  6.0   7.0      1.18
#
#                                      full_address                street  \
# 829            B-2 Monte Elena, Dorado, PR, 00949       B-2 Monte Elena
# 10344      46 Water Isle, Saint Thomas, VI, 00802         46 Water Isle
# 10351      10 Water Isle, Saint Thomas, VI, 00802         10 Water Isle
# 24237             955 River Rd, Agawam, MA, 01001          955 River Rd
# ...

# %%
house_df=house_df.reset_index(level=None, drop=True, inplace=False)

# %%
house_df
# Out:
#         status      price  bed  bath  acre_lot  \
# 0     for_sale   110000.0  7.0   3.0      0.09
# 1     for_sale   950000.0  5.0   4.0      0.99
# 2     for_sale  6899000.0  4.0   6.0      0.83
# 3     for_sale   525000.0  3.0   3.0      0.45
# 4     for_sale   289900.0  3.0   2.0      0.36
# ...        ...        ...  ...   ...       ...
# 6209  for_sale   545000.0  2.0   1.0      0.15
# 6210  for_sale   599000.0  5.0   2.0      0.40
# 6211  for_sale   749000.0  2.0   1.0      0.26
# 6212  for_sale   495000.0  3.0   2.0      0.15
# 6213  for_sale  3995000.0  6.0   7.0      1.18
#
#                                    full_address                street  \
# 0            B-2 Monte Elena, Dorado, PR, 00949       B-2 Monte Elena
# 1        46 Water Isle, Saint Thomas, VI, 00802         46 Water Isle
# 2        10 Water Isle, Saint Thomas, VI, 00802         10 Water Isle
# 3               955 River Rd, Agawam, MA, 01001          955 River Rd
# ...

# %%
house_df['house_size']=house_df['house_size'].astype('int')

# %%
house_df.loc[1:502, 'status']= 'for_rent'

# %%
house_df.value_counts('status')
# Out:
# status
# for_sale    5712
# for_rent     502
# dtype: int64

# %% [raw]
#  DROP TABLE if exists house cascade;
#         CREATE TABLE house (
#         house_id SERIAL PRIMARY KEY NOT NULL,
#         price FLOAT NOT NULL,
#         bed INT,
#         bath INT,
#         house_size INT,
#         acre_lot FLOAT,
#         adresse_id INT,
#         nom_status varchar(255),
#         FOREIGN KEY (adresse_id)
#                 REFERENCES adresse (adresse_id)
#                 ON UPDATE CASCADE ON DELETE CASCADE,
#         FOREIGN KEY (nom_status)
#                 REFERENCES status (nom_status)
#                 ON UPDATE CASCADE ON DELETE CASCADE

# %%
house_columns=['price', 'bed','bath', 'house_size', 'acre_lot']
adresse_columns=['street', 'city','state', 'zip_code']
house_tb_df =house_df[house_columns]
adresse_df=house_df[adresse_columns]
status_df=house_df['status']

# %%
status_df
# Out:
# 0       for_sale
# 1       for_rent
# 2       for_rent
# 3       for_rent
# 4       for_rent
#           ...
# 6209    for_sale
# 6210    for_sale
# 6211    for_sale
# 6212    for_sale
# 6213    for_sale
# Name: status, Length: 6214, dtype: object

# %% [markdown]
# status_df.rename(columns={'status': 'nom_status'}, inplace=True)

# %%
house_tb_df.dtypes
# Out:
# price         float64
# bed           float64
# bath          float64
# house_size      int32
# acre_lot      float64
# dtype: object

# %%
adresse_df.shape
# Out:
# (6214, 4)

# %%
adresse_df.dtypes
# Out:
# street       object
# city         object
# state        object
# zip_code    float64
# dtype: object

# %% [raw]
# house_tb_df['house_size']=house_tb_df['house_size'].fillna(0)

# %%
house_df.dtypes
# Out:
# status           object
# price           float64
# bed             float64
# bath            float64
# acre_lot        float64
# full_address     object
# street           object
# city             object
# state            object
# zip_code        float64
# house_size        int32
# sold_date        object
# dtype: object

# %%
house_df.shape
# Out:
# (6214, 12)

# %% [markdown]
# house_df['status'].replace(to_replace=[2,30,40,50,600,660,870], value='for_sale')

# %%
house_df.value_counts('status')
# Out:
# status
# for_sale    5712
# for_rent     502
# dtype: int64

# %%
try:
    conn = psycopg2.connect(
          user = "postgres",
          password = "toor",
          host = "localhost",
          port = "5433",
          database = "postgres"
    )
    cur = conn.cursor()
    # Afficher la version de PostgreSQL 
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print("Version : ", version,"\n")
    
    sql = '''
        DROP TABLE if exists adresse cascade;
        CREATE TABLE adresse (
        adresse_id SERIAL PRIMARY KEY NOT NULL,
        street TEXT NOT NULL,
        city varchar(255) NOT NULL,
        state varchar(255) NOT NULL,
        zip_code INT NOT NULL
        
      ); 
      DROP TABLE if exists status cascade;
      CREATE TABLE status (
        nom_status VARCHAR(255) PRIMARY KEY NOT NULL
      ); 
      
        DROP TABLE if exists house cascade;
        CREATE TABLE house (
        house_id SERIAL PRIMARY KEY NOT NULL,
        price FLOAT NOT NULL,
        bed INT,
        bath INT,
        house_size BIGINT,
        acre_lot FLOAT
      ); 
      
        '''
    
    cur.execute(sql)
    conn.commit()
    print("Table créée avec succès dans PostgreSQL")
  
  
    #fermeture de la connexion à la base de données
    cur.close()
    conn.close()
    print("La connexion PostgreSQL est fermée")
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 14.4, compiled by Visual C++ build 1914, 64-bit',)
#
# Table créée avec succès dans PostgreSQL
# La connexion PostgreSQL est fermée

# %%
try:
    conn = psycopg2.connect(
          user = "postgres",
          password = "toor",
          host = "localhost",
          port = "5433",
          database = "postgres"
    )
    conn.autocommit = True
    with conn.cursor() as cur:
        # Afficher la version de PostgreSQL 
        cur.execute("SELECT version();")
        version = cur.fetchone()
        print("Version : ", version,"\n")
    
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 14.4, compiled by Visual C++ build 1914, 64-bit',)

# %%
addr_tup = list(set([tuple(x) for x in adresse_df.to_numpy()]))
addr_tup
# Out:
# [('4 West St', 'Hadley', 'Massachusetts', 1035.0),
#  ('627 Winter St', 'Framingham', 'Massachusetts', 1702.0),
#  ('110 Quaker Ln S', 'West Hartford', 'Connecticut', 6119.0),
#  ('21 Mayflower Rd', 'West Yarmouth', 'Massachusetts', 2673.0),
#  ('17 Winthrop Rd', 'Plymouth', 'Massachusetts', 2360.0),
#  ('22 Noel St', 'Ludlow', 'Massachusetts', 1056.0),
#  ('28 Gorham St', 'Chelmsford', 'Massachusetts', 1824.0),
#  ('122 Crestridge Dr', 'Vernon', 'Connecticut', 6066.0),
#  ('38 Barber Ave', 'Warwick', 'Rhode Island', 2886.0),
#  ('29 Oaks Rd', 'Framingham', 'Massachusetts', 1702.0),
#  ('97 High St', 'Watertown', 'Connecticut', 6795.0),
#  ('42 Lepage Rd', 'Windsor', 'Connecticut', 6095.0),
#  ('29 Range Hill Dr', 'Vernon', 'Connecticut', 6066.0),
#  ('35 Ledgewood Rd', 'Watertown', 'Connecticut', 6795.0),
#  ('99 Meadow Trl', 'Coventry', 'Connecticut', 6238.0),
#  ('318 George Schnopp Rd', 'Hinsdale', 'Massachusetts', 1235.0),
#  ('74 Orange St', 'Hartford', 'Connecticut', 6106.0),
# ...

# %%
adress_column=list(adresse_df.columns)
adress_column
# Out:
# ['street', 'city', 'state', 'zip_code']

# %%
for elem in addr_tup:
    elems = "INSERT INTO adresse("+adress_column[0]+","+adress_column[1]+","+adress_column[2]+","+adress_column[3]+") VALUES(%s, %s, %s, %s)"
    quer=(elem[0],elem[1],elem[2],elem[3])
    #print(quer)
    #print(elems)
    with conn.cursor() as cur:
        cur.execute(elems,quer)
        conn.commit()

# %%
house_tb_df.head(100)
# Out:
#         price  bed  bath  house_size  acre_lot
# 0    110000.0  7.0   3.0        1192      0.09
# 1    950000.0  5.0   4.0        5000      0.99
# 2   6899000.0  4.0   6.0        4600      0.83
# 3    525000.0  3.0   3.0        2314      0.45
# 4    289900.0  3.0   2.0        1276      0.36
# ..        ...  ...   ...         ...       ...
# 95   235000.0  2.0   1.0        1200      0.27
# 96   449000.0  3.0   3.0        1916      0.40
# 97   995000.0  5.0   4.0        4468      0.72
# 98   325000.0  3.0   2.0        1336      0.54
# 99   399999.0  2.0   1.0        1072      0.50
#
# [100 rows x 5 columns]

# %% [markdown]
# for
# list(filter(lambda x: x!= np.inf, house_tb_df))

# %% [markdown]
# house_tb_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# house_tb_df.dropna(subset=["price", "bed","bath","house_size","acre_lot"], how="all", inplace=True)

# %% [markdown]
# house_tb_df.dropna()

# %%
house_tb_df.head(600)
# Out:
#            price  bed  bath  house_size  acre_lot
# 829     110000.0  7.0   3.0        1192      0.09
# 10344   950000.0  5.0   4.0        5000      0.99
# 10351  6899000.0  4.0   6.0        4600      0.83
# 24237   525000.0  3.0   3.0        2314      0.45
# 24238   289900.0  3.0   2.0        1276      0.36
# ...          ...  ...   ...         ...       ...
# 30473   225000.0  3.0   1.0        1056      0.30
# 30474   299900.0  3.0   2.0        1094      0.28
# 30475   700000.0  4.0   3.0        2822      0.45
# 30477   199900.0  3.0   1.0         912      0.26
# 30489   229900.0  3.0   1.0        1248      0.17
#
# [600 rows x 5 columns]

# %%
house_tb_df['price']= pd.to_numeric(house_tb_df['price'], errors='coerce')
house_tb_df['price']= house_tb_df['price'].dropna()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\1229824490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['price']= pd.to_numeric(house_tb_df['price'], errors='coerce')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\1229824490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['price']= house_tb_df['price'].dropna()

# %%
rentValue_df=

# %%
house_tb_df['house_size']
# Out:
# 0          920.0
# 1         1527.0
# 2          748.0
# 3         1800.0
# 4            NaN
#            ...
# 203086       NaN
# 203093       NaN
# 203094       NaN
# 203095    2579.0
# 203107    2449.0
# Name: house_size, Length: 20919, dtype: float64

# %%
house_tb_df['bed']= pd.to_numeric(house_tb_df['bed'], errors='coerce')
house_tb_df['bed']= house_tb_df['bed'].dropna()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\2030801184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['bed']= pd.to_numeric(house_tb_df['bed'], errors='coerce')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\2030801184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['bed']= house_tb_df['bed'].dropna()

# %%
house_tb_df['house_size']= pd.to_numeric(house_tb_df['house_size'], errors='coerce')
house_tb_df['house_size']= house_tb_df['house_size'].dropna()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\721851172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['house_size']= pd.to_numeric(house_tb_df['house_size'], errors='coerce')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\721851172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['house_size']= house_tb_df['house_size'].dropna()

# %%
house_tb_df['bath']= pd.to_numeric(house_tb_df['bath'], errors='coerce')
house_tb_df['bath']= house_tb_df['bath'].dropna()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\22508750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['bath']= pd.to_numeric(house_tb_df['bath'], errors='coerce')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\22508750.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['bath']= house_tb_df['bath'].dropna()

# %%
house_tb_df['acre_lot']= pd.to_numeric(house_tb_df['acre_lot'], errors='coerce')
house_tb_df['acre_lot']= house_tb_df['acre_lot'].dropna()
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\1036003706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['acre_lot']= pd.to_numeric(house_tb_df['acre_lot'], errors='coerce')
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_22188\1036003706.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['acre_lot']= house_tb_df['acre_lot'].dropna()

# %%
house_tb_df['house_size']=house_tb_df['house_size'].astype('int')
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_8092\874756198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_tb_df['house_size']=house_tb_df['house_size'].astype('int')

# %%
house_tb_df.dtypes
# Out:
# price         float64
# bed           float64
# bath          float64
# house_size      int32
# acre_lot      float64
# dtype: object

# %%
house_tb_df['bath']=house_tb_df['bath'].astype('int')

# %%
tuples = list(set([tuple(x) for x in house_tb_df.to_numpy()]))
tuples
# Out:
# [(239999.0, 3.0, 1.0, 924.0, 0.11),
#  (579000.0, 4.0, 4.0, 3577.0, 0.77),
#  (1250000.0, 7.0, 4.0, 3373.0, 0.11),
#  (274999.0, 3.0, 2.0, 1112.0, 0.28),
#  (275000.0, 3.0, 1.0, 1200.0, 0.08),
#  (299999.0, 4.0, 2.0, 1645.0, 0.26),
#  (198000.0, 3.0, 1.0, 876.0, 0.23),
#  (1350000.0, 9.0, 9.0, 4940.0, 0.7),
#  (839500.0, 3.0, 2.0, 812.0, 0.15),
#  (11890000.0, 11.0, 6.0, 5850.0, 85.0),
#  (217900.0, 2.0, 1.0, 1040.0, 0.18),
#  (749000.0, 4.0, 3.0, 1964.0, 0.13),
#  (669000.0, 4.0, 3.0, 2560.0, 1.15),
#  (479900.0, 3.0, 1.0, 1149.0, 0.42),
#  (205000.0, 2.0, 1.0, 950.0, 0.16),
#  (1579900.0, 5.0, 4.0, 5291.0, 1.15),
#  (985000.0, 9.0, 3.0, 3864.0, 0.11),
#  (1299000.0, 2.0, 2.0, 1328.0, 0.03),
#  (494900.0, 3.0, 3.0, 2000.0, 0.45),
#  (250000.0, 3.0, 1.0, 1100.0, 0.41),
#  (350000.0, 3.0, 2.0, 1092.0, 0.13),
#  (789000.0, 2.0, 1.0, 1004.0, 0.02),
#  (699000.0, 3.0, 2.0, 2370.0, 0.23),
#  (749900.0, 3.0, 3.0, 2583.0, 0.67),
#  (695000.0, 5.0, 3.0, 2328.0, 0.24),
# ...

# %%
house_tb_df.columns
# Out:
# Index(['price', 'bed', 'bath', 'house_size', 'acre_lot'], dtype='object')

# %%
cols = list(house_tb_df.columns)
cols
# Out:
# ['price', 'bed', 'bath', 'house_size', 'acre_lot']

# %%
for elt in tuples:
    elts = "INSERT INTO house("+cols[0]+","+cols[1]+","+cols[2]+","+cols[3]+","+cols[4]+") VALUES(%s, %s, %s, %s, %s)"
    quer=(elt[0],elt[1],elt[2],elt[3],elt[4])
    print(quer)
    print(elts)
    with conn.cursor() as cur:
        cur.execute(elts,quer)
        conn.commit()
# Out:
# (239999.0, 3.0, 1.0, 924.0, 0.11)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (579000.0, 4.0, 4.0, 3577.0, 0.77)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (1250000.0, 7.0, 4.0, 3373.0, 0.11)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (274999.0, 3.0, 2.0, 1112.0, 0.28)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (275000.0, 3.0, 1.0, 1200.0, 0.08)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (299999.0, 4.0, 2.0, 1645.0, 0.26)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (198000.0, 3.0, 1.0, 876.0, 0.23)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (1350000.0, 9.0, 9.0, 4940.0, 0.7)
# INSERT INTO house(price,bed,bath,house_size,acre_lot) VALUES(%s, %s, %s, %s, %s)
# (839500.0, 3.0, 2.0, 812.0, 0.15)
# ...

# %% [markdown]
# query = "INSERT INTO house(%s, %s, %s, %s, %s) VALUES({},{},{},{},{})".format(col[0],col[1],col[2],col[3],col[4])

# %% [markdown]
# try:
#     cur.execute(query)
#     conn.commit()
#
# except (Exception, psycopg2.Error) as error :
#     print ("Erreur lors de la connexion à PostgreSQL", error)
#     conn.rollback()

# %% [markdown]
# """
# Using cursor.executemany() to insert the dataframe
# """
# tuples = list(set([tuple(x) for x in house_tb_df.to_numpy()]))
#
#
# cols = ','.join(list(house_tb_df.columns))
#
# query = "INSERT INTO (%s, %s, %s,%s, %s) VALUES(%%s,%%s,%%s,%%s, %%s)" % (
#     table, cols)
#
# try:
#     cur.execute(query, tuples)
#     conn.commit()
#
# except (Exception, psycopg2.DatabaseError) as error:
#     print("Error: %s" % error)
#     conn.rollback()

# %%
requete=''''''

# %%
 sql = ''' DROP TABLE if exists status cascade;
      CREATE TABLE status (
        nom_status VARCHAR(255) PRIMARY KEY NOT NULL
      );'''

# %%
with conn.cursor() as cur:
        cur.execute(sql)
        conn.commit()

# %%
status_df.values
# Out:
# array(['for_sale', 'for_rent', 'for_rent', ..., 'for_sale', 'for_sale',
#        'for_sale'], dtype=object)

# %%
status_df.unique
# Out:
# <bound method Series.unique of 0       for_sale
# 1       for_rent
# 2       for_rent
# 3       for_rent
# 4       for_rent
#           ...
# 6209    for_sale
# 6210    for_sale
# 6211    for_sale
# 6212    for_sale
# 6213    for_sale
# Name: status, Length: 6214, dtype: object>

# %%
for x in status_df.values:
    eltst = "INSERT INTO status(nom_status) VALUES(%s)"
    print(eltst)
    with conn.cursor() as cur:
        cur.execute(eltst, x)
        conn.commit()
# Out:
# INSERT INTO status(nom_status) VALUES(%s)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
#       3 print(eltst)
#       4 with conn.cursor() as cur:
# ----> 5     cur.execute(eltst, x)
#       6     conn.commit()
#
# TypeError: not all arguments converted during string formatting

# %%
import mat
